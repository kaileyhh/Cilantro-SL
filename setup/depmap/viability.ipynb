# %%
import pandas as pd
import numpy as np

# %%
df_corr = pd.read_csv("/work/magroup/kaileyhu/datasets/depmap/CRISPRGeneEffect.csv")

# %%
df_corr.set_index('Unnamed: 0', inplace = True)

# %%
np.max(np.max(df_corr))
# Out:
# 4.387553563976993

# %%
np.min(np.min(df_corr))
# Out:
# -5.632497179747052

# %%
df = pd.read_csv("/work/magroup/kaileyhu/datasets/depmap/OmicsExpressionProteinCodingGenesTPMLogp1.csv")

# %%
df.set_index('Unnamed: 0', inplace = True)

# %%
len(set(df.index) & set(df_corr.index))
# Out:
# 1021

# %%
df = pd.read_hdf("/work/magroup/kaileyhu/res/perturbed/gf_12L_30M_i2048_SL/generated_df/delta_embs_pca_32.h5", "table")

# %%
temp = pd.read_hdf("/work/magroup/kaileyhu/res/perturbed/gf_12L_30M_i2048_SL/ESM_df/ESM2_64_film_all.h5", "table")

# %%
df.index = list(map(literal_eval, list(df.index)))

# %%
df = df.drop(columns='viability score')

# %%
df.to_hdf("/work/magroup/kaileyhu/res/perturbed/gf_12L_30M_i2048_SL/generated_df/delta_embs_pca_32.h5", "table")

# %%
from ast import literal_eval

# %%
literal_eval(df.index[0])
# Out:
# ('ACH-000001', 'gene_ENSG00000051341')

# %%
df.index = list(map(lambda x : str(x), list(df.index)))

# %%
df
# Out:
#                                                0         1         2  \
# ('ACH-000001', 'gene_ENSG00000051341')  0.105654  0.045416 -0.004091
# ('ACH-000004', 'gene_ENSG00000051341')  0.062131  0.024018 -0.004748
# ('ACH-000005', 'gene_ENSG00000051341')  0.036501 -0.031987  0.006276
# ('ACH-000007', 'gene_ENSG00000051341')  0.009909 -0.109031 -0.031778
# ('ACH-000009', 'gene_ENSG00000051341') -0.145955 -0.015284 -0.061865
# ...                                          ...       ...       ...
# ('ACH-002834', 'gene_ENSG00000100926')  0.010732 -0.001760  0.007685
# ('ACH-002847', 'gene_ENSG00000100926')  0.131617  0.017289  0.012651
# ('ACH-002922', 'gene_ENSG00000100926')  0.290133  0.144205 -0.010087
# ('ACH-002925', 'gene_ENSG00000100926')  0.237871  0.070195 -0.037511
# ('ACH-002926', 'gene_ENSG00000100926') -0.025780  0.032786  0.006530
#
#                                                3         4         5  \
# ...
