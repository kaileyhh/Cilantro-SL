# %% [markdown]
# ### Extract embeddings from GenePT
# https://www.biorxiv.org/content/10.1101/2023.10.16.562533v2.full

# %%
import json
import numpy as np
import openai

# remember to set your OpenAI api key
openai.api_key = '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'

# %%
def get_gpt_embedding(text, model="text-embedding-ada-002"):
    text = text.replace("\n", " ")
    return np.array(openai.Embedding.create(input = [text], model=model)['data'][0]['embedding'])
