# %% [markdown]
# # (0) Download data

# %%
import gdown

# %%
data_dir = "../data"

folder_id = "1HFjP5Lwa1RoGKTpMYSoCxYNNwSFqu5dE"

gdown.download_folder(id=folder_id, output=data_dir, quiet=False, use_cookies=False)
# Out:
# Retrieving folder contents
# Processing file 1vx4vZYieTIm96F7BiVyju5KU6f53dkne gene2vec_embs.pt
# Processing file 1EfEc_N_LWrssVuJUzhsEInUu8zaNJr_S OmicsExpressionProteinCodingGenesTPMLogp1.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1vx4vZYieTIm96F7BiVyju5KU6f53dkne
# From (redirected): https://drive.google.com/uc?id=1vx4vZYieTIm96F7BiVyju5KU6f53dkne&confirm=t&uuid=6d40f90d-21de-482c-bf30-316d83d4dc18
# To: /Users/kaileyhua/Desktop/research/Cilantro-SL/data/gene2vec_embs.pt
# 100%|██████████| 32.4M/32.4M [00:00<00:00, 35.3MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1EfEc_N_LWrssVuJUzhsEInUu8zaNJr_S
# From (redirected): https://drive.google.com/uc?id=1EfEc_N_LWrssVuJUzhsEInUu8zaNJr_S&confirm=t&uuid=0902ec6f-3b56-4784-af07-95b9b25d1d64
# To: /Users/kaileyhua/Desktop/research/Cilantro-SL/data/OmicsExpressionProteinCodingGenesTPMLogp1.csv
# 100%|██████████| 450M/450M [00:09<00:00, 46.7MB/s]
# Download completed
# ['../data/gene2vec_embs.pt',
#  '../data/OmicsExpressionProteinCodingGenesTPMLogp1.csv']
