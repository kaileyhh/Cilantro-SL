# %% [markdown]
# ### Input processing for the gf-12L-2048 model using only the HVG dataset

# %%
from data_generator import data_generator
import pandas as pd
import ast
from tqdm import tqdm
# Out:
# 2024-12-03 18:55:24.268526: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-03 18:55:24.282583: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-03 18:55:24.296790: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-03 18:55:24.301023: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
dg = data_generator(
        is_hvg = True,
        ko_file_dir = "/work/magroup/kaileyhu/res/gf_12L_30M_i2048_HVG/perturbed_embs/",
        sub_file_dir = "/work/magroup/kaileyhu/res/gf_12L_30M_i2048_HVG/subtracted_embs/",
        output_dir = "/work/magroup/kaileyhu/res/gf_12L_30M_i2048_HVG/pretrained",
        model_path = "/work/magroup/kaileyhu/Geneformer/gf-12L-30M-i2048/",
        model_type = "Pretrained",
        emb_mode = "cell",
        emb_dim = 512,
        n_classes = 0,
        dataset = "/work/magroup/kaileyhu/res/hvg_500_tokenized_2048.dataset")

# %%
dg.concat_gene_embs(
    gene_emb_dir = "/work/magroup/kaileyhu/res/hvg_500_tokenized_2048_GENES.csv",
    df_dir = "/work/magroup/kaileyhu/res/gf_12L_30M_i2048_HVG/pretrained/gene_patient_emb_mat.csv")
# Out:
# 100%|██████████| 328619/328619 [00:54<00:00, 6011.96it/s]
