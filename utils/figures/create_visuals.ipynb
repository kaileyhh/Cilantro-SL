# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.rcParams['font.size'] = 8

labels = ["general model", "haematopoietic_and_lymphoid_tissue", "large_intestine", "pancreas", "salivary_gland", "Uachus", "lung", "breast"]
accs = [0.882050372472508, 0.9404188378723822, 0.9426070038910506, 0.9428822495606327, 0.9705882352941176, 0.9574468085106383, 0.9641820627167834, 0.9454828660436138]

plt.legend(loc='best', fontsize=6)
plt.ylabel("accuracy")

bars = plt.bar(labels, accs)
plt.bar_label(bars)
plt.xticks(rotation=30)
# Out:
# /tmp/ipykernel_3221436/1011687516.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best', fontsize=6)
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'general model'),
#   Text(1, 0, 'haematopoietic_and_lymphoid_tissue'),
#   Text(2, 0, 'large_intestine'),
#   Text(3, 0, 'pancreas'),
#   Text(4, 0, 'salivary_gland'),
#   Text(5, 0, 'Uachus'),
#   Text(6, 0, 'lung'),
#   Text(7, 0, 'breast')])
